# %% [markdown]
# ## Description
# Blablabla...

# %%
import glob
import numpy
import pandas
# import seaborn
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype'] = 'none'
from tqdm import tqdm

# %%
from IPython.display import display, HTML, Math, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import sys
sys.path.append('../../')

# %%
import coralme
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-50cce1bb1600> in <module>
# ----> 1 import coralme
#
# /mount_point/coralme/__init__.py in <module>
#      10         pass
#      11 else:
# ---> 12         import coralme.solver.solver
#      13
#      14 import coralme.util
#
# /mount_point/coralme/solver/solver.py in <module>
#       6 import sympy
#       7
# ----> 8 from coralme.solver import qwarmLP, warmLP, qvaryME
#       9
#      10 def makeME_VA(S, b, c, xl, xu, csense, obj_inds, obj_coeffs):
#
# ImportError: libgfortran.so.3: cannot open shared object file: No such file or directory

# %%
# %%bash
# apt-file find libgfortran.so
# Out:
# lib32gfortran-10-dev: /usr/lib/gcc/x86_64-linux-gnu/10/32/libgfortran.so
# lib32gfortran-10-dev-amd64-cross: /usr/lib/gcc-cross/x86_64-linux-gnu/10/32/libgfortran.so
# lib32gfortran-10-dev-mips64-cross: /usr/lib/gcc-cross/mips64-linux-gnuabi64/10/32/libgfortran.so
# lib32gfortran-10-dev-mips64el-cross: /usr/lib/gcc-cross/mips64el-linux-gnuabi64/10/32/libgfortran.so
# lib32gfortran-10-dev-mips64r6-cross: /usr/lib/gcc-cross/mipsisa64r6-linux-gnuabi64/10/32/libgfortran.so
# lib32gfortran-10-dev-mips64r6el-cross: /usr/lib/gcc-cross/mipsisa64r6el-linux-gnuabi64/10/32/libgfortran.so
# lib32gfortran-10-dev-ppc64-cross: /usr/lib/gcc-cross/powerpc64-linux-gnu/10/32/libgfortran.so
# lib32gfortran-10-dev-s390x-cross: /usr/lib/gcc-cross/s390x-linux-gnu/10/32/libgfortran.so
# lib32gfortran-10-dev-sparc64-cross: /usr/lib/gcc-cross/sparc64-linux-gnu/10/32/libgfortran.so
# lib32gfortran-10-dev-x32-cross: /usr/lib/gcc-cross/x86_64-linux-gnux32/10/32/libgfortran.so
# lib32gfortran-9-dev: /usr/lib/gcc/x86_64-linux-gnu/9/32/libgfortran.so
# lib32gfortran-9-dev-amd64-cross: /usr/lib/gcc-cross/x86_64-linux-gnu/9/32/libgfortran.so
# lib32gfortran-9-dev-ppc64-cross: /usr/lib/gcc-cross/powerpc64-linux-gnu/9/32/libgfortran.so
# lib32gfortran-9-dev-s390x-cross: /usr/lib/gcc-cross/s390x-linux-gnu/9/32/libgfortran.so
# lib32gfortran-9-dev-sparc64-cross: /usr/lib/gcc-cross/sparc64-linux-gnu/9/32/libgfortran.so
# lib32gfortran-9-dev-x32-cross: /usr/lib/gcc-cross/x86_64-linux-gnux32/9/32/libgfortran.so
# lib32gfortran5: /usr/lib32/libgfortran.so.5
# lib32gfortran5: /usr/lib32/libgfortran.so.5.0.0
# lib32gfortran5-amd64-cross: /usr/x86_64-linux-gnu/lib32/libgfortran.so.5
# lib32gfortran5-amd64-cross: /usr/x86_64-linux-gnu/lib32/libgfortran.so.5.0.0
# lib32gfortran5-mips64-cross: /usr/mips64-linux-gnuabi64/libo32/libgfortran.so.5
# lib32gfortran5-mips64-cross: /usr/mips64-linux-gnuabi64/libo32/libgfortran.so.5.0.0
# lib32gfortran5-mips64el-cross: /usr/mips64el-linux-gnuabi64/libo32/libgfortran.so.5
# lib32gfortran5-mips64el-cross: /usr/mips64el-linux-gnuabi64/libo32/libgfortran.so.5.0.0
# lib32gfortran5-mips64r6-cross: /usr/mipsisa64r6-linux-gnuabi64/libo32/libgfortran.so.5
# lib32gfortran5-mips64r6-cross: /usr/mipsisa64r6-linux-gnuabi64/libo32/libgfortran.so.5.0.0
# lib32gfortran5-mips64r6el-cross: /usr/mipsisa64r6el-linux-gnuabi64/libo32/libgfortran.so.5
# lib32gfortran5-mips64r6el-cross: /usr/mipsisa64r6el-linux-gnuabi64/libo32/libgfortran.so.5.0.0
# lib32gfortran5-ppc64-cross: /usr/powerpc64-linux-gnu/lib32/libgfortran.so.5
# lib32gfortran5-ppc64-cross: /usr/powerpc64-linux-gnu/lib32/libgfortran.so.5.0.0
# lib32gfortran5-s390x-cross: /usr/s390x-linux-gnu/lib32/libgfortran.so.5
# lib32gfortran5-s390x-cross: /usr/s390x-linux-gnu/lib32/libgfortran.so.5.0.0
# lib32gfortran5-sparc64-cross: /usr/sparc64-linux-gnu/lib32/libgfortran.so.5
# lib32gfortran5-sparc64-cross: /usr/sparc64-linux-gnu/lib32/libgfortran.so.5.0.0
# lib32gfortran5-x32-cross: /usr/x86_64-linux-gnux32/lib32/libgfortran.so.5
# lib32gfortran5-x32-cross: /usr/x86_64-linux-gnux32/lib32/libgfortran.so.5.0.0
# lib64gfortran-10-dev-i386-cross: /usr/lib/gcc-cross/i686-linux-gnu/10/64/libgfortran.so
# lib64gfortran-10-dev-mips-cross: /usr/lib/gcc-cross/mips-linux-gnu/10/64/libgfortran.so
# lib64gfortran-10-dev-mipsel-cross: /usr/lib/gcc-cross/mipsel-linux-gnu/10/64/libgfortran.so
# lib64gfortran-10-dev-mipsr6-cross: /usr/lib/gcc-cross/mipsisa32r6-linux-gnu/10/64/libgfortran.so
# lib64gfortran-10-dev-mipsr6el-cross: /usr/lib/gcc-cross/mipsisa32r6el-linux-gnu/10/64/libgfortran.so
# lib64gfortran-10-dev-powerpc-cross: /usr/lib/gcc-cross/powerpc-linux-gnu/10/64/libgfortran.so
# lib64gfortran-10-dev-x32-cross: /usr/lib/gcc-cross/x86_64-linux-gnux32/10/64/libgfortran.so
# lib64gfortran-9-dev-i386-cross: /usr/lib/gcc-cross/i686-linux-gnu/9/64/libgfortran.so
# lib64gfortran-9-dev-powerpc-cross: /usr/lib/gcc-cross/powerpc-linux-gnu/9/64/libgfortran.so
# lib64gfortran-9-dev-x32-cross: /usr/lib/gcc-cross/x86_64-linux-gnux32/9/64/libgfortran.so
# lib64gfortran5-i386-cross: /usr/i686-linux-gnu/lib64/libgfortran.so.5
# lib64gfortran5-i386-cross: /usr/i686-linux-gnu/lib64/libgfortran.so.5.0.0
# lib64gfortran5-mips-cross: /usr/mips-linux-gnu/lib64/libgfortran.so.5
# lib64gfortran5-mips-cross: /usr/mips-linux-gnu/lib64/libgfortran.so.5.0.0
# lib64gfortran5-mipsel-cross: /usr/mipsel-linux-gnu/lib64/libgfortran.so.5
# lib64gfortran5-mipsel-cross: /usr/mipsel-linux-gnu/lib64/libgfortran.so.5.0.0
# lib64gfortran5-mipsr6-cross: /usr/mipsisa32r6-linux-gnu/lib64/libgfortran.so.5
# lib64gfortran5-mipsr6-cross: /usr/mipsisa32r6-linux-gnu/lib64/libgfortran.so.5.0.0
# lib64gfortran5-mipsr6el-cross: /usr/mipsisa32r6el-linux-gnu/lib64/libgfortran.so.5
# lib64gfortran5-mipsr6el-cross: /usr/mipsisa32r6el-linux-gnu/lib64/libgfortran.so.5.0.0
# lib64gfortran5-powerpc-cross: /usr/powerpc-linux-gnu/lib64/libgfortran.so.5
# lib64gfortran5-powerpc-cross: /usr/powerpc-linux-gnu/lib64/libgfortran.so.5.0.0
# lib64gfortran5-x32-cross: /usr/x86_64-linux-gnux32/lib64/libgfortran.so.5
# lib64gfortran5-x32-cross: /usr/x86_64-linux-gnux32/lib64/libgfortran.so.5.0.0
# libgfortran-10-dev: /usr/lib/gcc/x86_64-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-alpha-cross: /usr/lib/gcc-cross/alpha-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-amd64-cross: /usr/lib/gcc-cross/x86_64-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-arm64-cross: /usr/lib/gcc-cross/aarch64-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-armel-cross: /usr/lib/gcc-cross/arm-linux-gnueabi/10/libgfortran.so
# libgfortran-10-dev-armhf-cross: /usr/lib/gcc-cross/arm-linux-gnueabihf/10/libgfortran.so
# libgfortran-10-dev-hppa-cross: /usr/lib/gcc-cross/hppa-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-i386-cross: /usr/lib/gcc-cross/i686-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-m68k-cross: /usr/lib/gcc-cross/m68k-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-mips-cross: /usr/lib/gcc-cross/mips-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-mips64-cross: /usr/lib/gcc-cross/mips64-linux-gnuabi64/10/libgfortran.so
# libgfortran-10-dev-mips64el-cross: /usr/lib/gcc-cross/mips64el-linux-gnuabi64/10/libgfortran.so
# libgfortran-10-dev-mips64r6-cross: /usr/lib/gcc-cross/mipsisa64r6-linux-gnuabi64/10/libgfortran.so
# libgfortran-10-dev-mips64r6el-cross: /usr/lib/gcc-cross/mipsisa64r6el-linux-gnuabi64/10/libgfortran.so
# libgfortran-10-dev-mipsel-cross: /usr/lib/gcc-cross/mipsel-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-mipsr6-cross: /usr/lib/gcc-cross/mipsisa32r6-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-mipsr6el-cross: /usr/lib/gcc-cross/mipsisa32r6el-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-powerpc-cross: /usr/lib/gcc-cross/powerpc-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-ppc64-cross: /usr/lib/gcc-cross/powerpc64-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-ppc64el-cross: /usr/lib/gcc-cross/powerpc64le-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-riscv64-cross: /usr/lib/gcc-cross/riscv64-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-s390x-cross: /usr/lib/gcc-cross/s390x-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-sh4-cross: /usr/lib/gcc-cross/sh4-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-sparc64-cross: /usr/lib/gcc-cross/sparc64-linux-gnu/10/libgfortran.so
# libgfortran-10-dev-x32-cross: /usr/lib/gcc-cross/x86_64-linux-gnux32/10/libgfortran.so
# libgfortran-9-dev: /usr/lib/gcc/x86_64-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-alpha-cross: /usr/lib/gcc-cross/alpha-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-amd64-cross: /usr/lib/gcc-cross/x86_64-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-arm64-cross: /usr/lib/gcc-cross/aarch64-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-armel-cross: /usr/lib/gcc-cross/arm-linux-gnueabi/9/libgfortran.so
# libgfortran-9-dev-armhf-cross: /usr/lib/gcc-cross/arm-linux-gnueabihf/9/libgfortran.so
# libgfortran-9-dev-hppa-cross: /usr/lib/gcc-cross/hppa-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-i386-cross: /usr/lib/gcc-cross/i686-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-m68k-cross: /usr/lib/gcc-cross/m68k-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-powerpc-cross: /usr/lib/gcc-cross/powerpc-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-ppc64-cross: /usr/lib/gcc-cross/powerpc64-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-ppc64el-cross: /usr/lib/gcc-cross/powerpc64le-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-riscv64-cross: /usr/lib/gcc-cross/riscv64-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-s390x-cross: /usr/lib/gcc-cross/s390x-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-sh4-cross: /usr/lib/gcc-cross/sh4-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-sparc64-cross: /usr/lib/gcc-cross/sparc64-linux-gnu/9/libgfortran.so
# libgfortran-9-dev-x32-cross: /usr/lib/gcc-cross/x86_64-linux-gnux32/9/libgfortran.so
# libgfortran5: /usr/lib/x86_64-linux-gnu/libgfortran.so.5
# libgfortran5: /usr/lib/x86_64-linux-gnu/libgfortran.so.5.0.0
# libgfortran5-alpha-cross: /usr/alpha-linux-gnu/lib/libgfortran.so.5
# libgfortran5-alpha-cross: /usr/alpha-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-amd64-cross: /usr/x86_64-linux-gnu/lib/libgfortran.so.5
# libgfortran5-amd64-cross: /usr/x86_64-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-arm64-cross: /usr/aarch64-linux-gnu/lib/libgfortran.so.5
# libgfortran5-arm64-cross: /usr/aarch64-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-armel-cross: /usr/arm-linux-gnueabi/lib/libgfortran.so.5
# libgfortran5-armel-cross: /usr/arm-linux-gnueabi/lib/libgfortran.so.5.0.0
# libgfortran5-armhf-cross: /usr/arm-linux-gnueabihf/lib/libgfortran.so.5
# libgfortran5-armhf-cross: /usr/arm-linux-gnueabihf/lib/libgfortran.so.5.0.0
# libgfortran5-hppa-cross: /usr/hppa-linux-gnu/lib/libgfortran.so.5
# libgfortran5-hppa-cross: /usr/hppa-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-i386-cross: /usr/i686-linux-gnu/lib/libgfortran.so.5
# libgfortran5-i386-cross: /usr/i686-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-m68k-cross: /usr/m68k-linux-gnu/lib/libgfortran.so.5
# libgfortran5-m68k-cross: /usr/m68k-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-mips-cross: /usr/mips-linux-gnu/lib/libgfortran.so.5
# libgfortran5-mips-cross: /usr/mips-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-mips64-cross: /usr/mips64-linux-gnuabi64/lib/libgfortran.so.5
# libgfortran5-mips64-cross: /usr/mips64-linux-gnuabi64/lib/libgfortran.so.5.0.0
# libgfortran5-mips64el-cross: /usr/mips64el-linux-gnuabi64/lib/libgfortran.so.5
# libgfortran5-mips64el-cross: /usr/mips64el-linux-gnuabi64/lib/libgfortran.so.5.0.0
# libgfortran5-mips64r6-cross: /usr/mipsisa64r6-linux-gnuabi64/lib/libgfortran.so.5
# libgfortran5-mips64r6-cross: /usr/mipsisa64r6-linux-gnuabi64/lib/libgfortran.so.5.0.0
# libgfortran5-mips64r6el-cross: /usr/mipsisa64r6el-linux-gnuabi64/lib/libgfortran.so.5
# libgfortran5-mips64r6el-cross: /usr/mipsisa64r6el-linux-gnuabi64/lib/libgfortran.so.5.0.0
# libgfortran5-mipsel-cross: /usr/mipsel-linux-gnu/lib/libgfortran.so.5
# libgfortran5-mipsel-cross: /usr/mipsel-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-mipsr6-cross: /usr/mipsisa32r6-linux-gnu/lib/libgfortran.so.5
# libgfortran5-mipsr6-cross: /usr/mipsisa32r6-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-mipsr6el-cross: /usr/mipsisa32r6el-linux-gnu/lib/libgfortran.so.5
# libgfortran5-mipsr6el-cross: /usr/mipsisa32r6el-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-powerpc-cross: /usr/powerpc-linux-gnu/lib/libgfortran.so.5
# libgfortran5-powerpc-cross: /usr/powerpc-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-ppc64-cross: /usr/powerpc64-linux-gnu/lib/libgfortran.so.5
# libgfortran5-ppc64-cross: /usr/powerpc64-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-ppc64el-cross: /usr/powerpc64le-linux-gnu/lib/libgfortran.so.5
# libgfortran5-ppc64el-cross: /usr/powerpc64le-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-riscv64-cross: /usr/riscv64-linux-gnu/lib/libgfortran.so.5
# libgfortran5-riscv64-cross: /usr/riscv64-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-s390x-cross: /usr/s390x-linux-gnu/lib/libgfortran.so.5
# libgfortran5-s390x-cross: /usr/s390x-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-sh4-cross: /usr/sh4-linux-gnu/lib/libgfortran.so.5
# libgfortran5-sh4-cross: /usr/sh4-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-sparc64-cross: /usr/sparc64-linux-gnu/lib/libgfortran.so.5
# libgfortran5-sparc64-cross: /usr/sparc64-linux-gnu/lib/libgfortran.so.5.0.0
# libgfortran5-x32-cross: /usr/x86_64-linux-gnux32/lib/libgfortran.so.5
# libgfortran5-x32-cross: /usr/x86_64-linux-gnux32/lib/libgfortran.so.5.0.0
# libn32gfortran-10-dev-mips-cross: /usr/lib/gcc-cross/mips-linux-gnu/10/n32/libgfortran.so
# libn32gfortran-10-dev-mips64-cross: /usr/lib/gcc-cross/mips64-linux-gnuabi64/10/n32/libgfortran.so
# libn32gfortran-10-dev-mips64el-cross: /usr/lib/gcc-cross/mips64el-linux-gnuabi64/10/n32/libgfortran.so
# libn32gfortran-10-dev-mips64r6-cross: /usr/lib/gcc-cross/mipsisa64r6-linux-gnuabi64/10/n32/libgfortran.so
# libn32gfortran-10-dev-mips64r6el-cross: /usr/lib/gcc-cross/mipsisa64r6el-linux-gnuabi64/10/n32/libgfortran.so
# libn32gfortran-10-dev-mipsel-cross: /usr/lib/gcc-cross/mipsel-linux-gnu/10/n32/libgfortran.so
# libn32gfortran-10-dev-mipsr6-cross: /usr/lib/gcc-cross/mipsisa32r6-linux-gnu/10/n32/libgfortran.so
# libn32gfortran-10-dev-mipsr6el-cross: /usr/lib/gcc-cross/mipsisa32r6el-linux-gnu/10/n32/libgfortran.so
# libn32gfortran5-mips-cross: /usr/mips-linux-gnu/lib32/libgfortran.so.5
# libn32gfortran5-mips-cross: /usr/mips-linux-gnu/lib32/libgfortran.so.5.0.0
# libn32gfortran5-mips64-cross: /usr/mips64-linux-gnuabi64/lib32/libgfortran.so.5
# libn32gfortran5-mips64-cross: /usr/mips64-linux-gnuabi64/lib32/libgfortran.so.5.0.0
# libn32gfortran5-mips64el-cross: /usr/mips64el-linux-gnuabi64/lib32/libgfortran.so.5
# libn32gfortran5-mips64el-cross: /usr/mips64el-linux-gnuabi64/lib32/libgfortran.so.5.0.0
# libn32gfortran5-mips64r6-cross: /usr/mipsisa64r6-linux-gnuabi64/lib32/libgfortran.so.5
# libn32gfortran5-mips64r6-cross: /usr/mipsisa64r6-linux-gnuabi64/lib32/libgfortran.so.5.0.0
# libn32gfortran5-mips64r6el-cross: /usr/mipsisa64r6el-linux-gnuabi64/lib32/libgfortran.so.5
# libn32gfortran5-mips64r6el-cross: /usr/mipsisa64r6el-linux-gnuabi64/lib32/libgfortran.so.5.0.0
# libn32gfortran5-mipsel-cross: /usr/mipsel-linux-gnu/lib32/libgfortran.so.5
# libn32gfortran5-mipsel-cross: /usr/mipsel-linux-gnu/lib32/libgfortran.so.5.0.0
# libn32gfortran5-mipsr6-cross: /usr/mipsisa32r6-linux-gnu/lib32/libgfortran.so.5
# libn32gfortran5-mipsr6-cross: /usr/mipsisa32r6-linux-gnu/lib32/libgfortran.so.5.0.0
# libn32gfortran5-mipsr6el-cross: /usr/mipsisa32r6el-linux-gnu/lib32/libgfortran.so.5
# libn32gfortran5-mipsr6el-cross: /usr/mipsisa32r6el-linux-gnu/lib32/libgfortran.so.5.0.0
# libx32gfortran-10-dev: /usr/lib/gcc/x86_64-linux-gnu/10/x32/libgfortran.so
# libx32gfortran-10-dev-amd64-cross: /usr/lib/gcc-cross/x86_64-linux-gnu/10/x32/libgfortran.so
# libx32gfortran-10-dev-i386-cross: /usr/lib/gcc-cross/i686-linux-gnu/10/x32/libgfortran.so
# libx32gfortran-9-dev: /usr/lib/gcc/x86_64-linux-gnu/9/x32/libgfortran.so
# libx32gfortran-9-dev-amd64-cross: /usr/lib/gcc-cross/x86_64-linux-gnu/9/x32/libgfortran.so
# libx32gfortran-9-dev-i386-cross: /usr/lib/gcc-cross/i686-linux-gnu/9/x32/libgfortran.so
# libx32gfortran5: /usr/libx32/libgfortran.so.5
# libx32gfortran5: /usr/libx32/libgfortran.so.5.0.0
# libx32gfortran5-amd64-cross: /usr/x86_64-linux-gnu/libx32/libgfortran.so.5
# libx32gfortran5-amd64-cross: /usr/x86_64-linux-gnu/libx32/libgfortran.so.5.0.0
# libx32gfortran5-i386-cross: /usr/i686-linux-gnu/libx32/libgfortran.so.5
# libx32gfortran5-i386-cross: /usr/i686-linux-gnu/libx32/libgfortran.so.5.0.0

# %%
import pickle, tqdm
with open('./MEModel-step2-iJL1678b-ME.pkl', 'rb') as infile:
    me = pickle.load(infile)

import coralme
coralme.io.json.save_json_me_model(me, 'MEModel-step2-iJL1678b-ME.json')

me.add_boundary(me.metabolites.li_c, type = 'sink');

me.optimize(max_mu = 1.0)
me.solution.to_frame()['fluxes'].to_csv('coralme-fluxes-from-model.txt', sep = '\t', header = False)
